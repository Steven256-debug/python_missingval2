# %% [markdown]
# <a href="https://colab.research.google.com/github/Steven256-debug/python_missingval2/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/hatieku-boateng/python_missingval.git
# Out:
# Cloning into 'python_missingval'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 10 (delta 1), reused 2 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (10/10), 4.08 KiB | 4.08 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd python_missingval
# Out:
# /content/python_missingval

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !rm -rf python_missingval

# %%
# !git clone https://github.com/hatieku-boateng/python_missingval
# Out:
# Cloning into 'python_missingval'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 10 (delta 1), reused 2 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (10/10), 4.08 KiB | 4.08 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# !rm -rf python_missingval
# !git clone https://github.com/hatieku-boateng/python_missingval.git
# Out:
# Cloning into 'python_missingval'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 14 (delta 2), reused 6 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (14/14), 10.96 KiB | 2.74 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# %cd python_missingval
# Out:
# /content/python_missingval/python_missingval
